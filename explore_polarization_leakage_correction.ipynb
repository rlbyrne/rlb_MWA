# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import sys
import numpy as np
sys.path.append('/Users/rubybyrne/rlb_MWA/sky_imaging')
import plot_fits
import plot_healpix_map
import healpix_utils

# %%
#Deconvolution run
for stokes in ['I','Q','U','V']:
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_survey_decon_4pol_Aug2019/output_data/1130776624_uniform_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-1,1])
# Out:
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.

# %%
#First pol leakage run
for stokes in ['I','Q','U','V']:
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Feb2020/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
# Out:
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.

# %%
#Second pol leakage run
for stokes in ['I','Q','U','V']:
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Mar2020/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
# Out:
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.

# %%
#Both together
for stokes in ['I','Q','U','V']:
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Feb2020/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
    
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Mar2020/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
# Out:
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.

# %%
#Check the 3rd trial against the 1st
for stokes in ['I','Q','U','V']:
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Feb2020/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
    
    plt.figure(figsize=(10,10))
    image1 = plot_fits.load_image(
        '/Volumes/Bilbo/rlb_fhd_outputs/diffuse_survey/fhd_rlb_diffuse_baseline_cut_optimal_weighting_Mar2020_2/output_data/1130776624_weighted_Residual_{}.fits'.format(stokes)
    )
    plot_fits.plot_fits_image(image1, ra_range=[40,60], dec_range=[-50,-10], colorbar_label='Flux Density (Jy/sr)',title='Stokes {}'.format(stokes),colorbar_range=[-20000,20000])
# Out:
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
# WARNING: Ignoring curved sky effects.
